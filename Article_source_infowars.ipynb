# %% [markdown]
# # Articles sources-Infowars

# %%
# Import
import requests
import nltk
import urllib.request
import time
import pandas, numpy
import pandas as pd 
import numpy as np

from bs4 import BeautifulSoup
from newspaper import Article

# %%
#Preparing the file to store the urls
df = pd.read_csv("C:\curso-ML-1\project\Pasta1.csv") 
df['Text']=""
##df =df.head(10000)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Word    0 non-null      object
#  1   Text    0 non-null      object
# dtypes: object(2)
# memory usage: 0.0+ bytes

# %%
#Select the source
URL1 = 'https://www.infowars.com/news/'

# %%
request1 = requests.get(URL1)

# %%
sources = request1.content
print(len(sources))
print(sources[1])
type(sources)
sources1 = sources.decode("utf-8") 
print(sources1[1])
##print(sources1)
# Out:
# 139689
# 33
# !

# %%
len1 = len(sources1)
print(len1)
marker =""
selector="OF"
url2=""
counter1=0
for i in range(len1):
    letter = sources1[i]
    marker = marker+letter
    len2 = len(marker)
    marker1 = marker[len2-4:len2]
    
    ##print(marker1)
    if marker1 == 'href':
        selector="ON"
        ##print(marker1) 

       
    if selector=="ON":
        ##print(selector)
        #sources2 =sources2+letter
        url2 = url2+letter
        
 
    
    if selector=="ON" and letter=='>':
        selector = "OF"
        url2 = url2[3:]
        ##print(url2[0:9])
        print(url2)
        len3 = len(url2)
        print("tamanho do url")
        print(len3)
        palavra1=""
        selector2 = "ON"
        for iy in range(len3):
            letra=url2[iy]
            ##print(iy)
            if letra == '"' and selector2=="ON":
                selector2 = "OFF"
                corte = iy
        print(corte)
        url2 = url2[0:corte]        
        print(url2)
        df = df.append([url2], ignore_index=True)
        ##df['Text'][counter1]=url2
        counter1 = counter1+1
        url2 = ""
# Out:
# 139632
# /manifest.json"/>
# tamanho do url
# 17
# 14
# /manifest.json
# https://www.infowars.com/wp-content/themes/infowars-sitegoals/images/mipmap-xhdpi/ic_launcher.png" />
# tamanho do url
# 101
# 97
# https://www.infowars.com/wp-content/themes/infowars-sitegoals/images/mipmap-xhdpi/ic_launcher.png
# //gmpg.org/xfn/11">
# tamanho do url
# 19
# 17
# //gmpg.org/xfn/11
# https://www.infowars.com/xmlrpc.php">
# tamanho do url
# 37
# 35
# https://www.infowars.com/xmlrpc.php
# https://cdnjs.cloudflare.com/ajax/libs/lightbox2/2.8.1/css/lightbox.css">
# tamanho do url
# 73
# 71
# https://cdnjs.cloudflare.com/ajax/libs/lightbox2/2.8.1/css/lightbox.css
# //cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" />
# tamanho do url
# 79
# 75
# //cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css
# //cdnjs.cloudflare.com' />
# tamanho do url
# 26
# 75
# //cdnjs.cloudflare.com' />
# //s.w.org' />
# tamanho do url
# 13
# 75
# //s.w.org' />
# ...

# %%
print(df)
# Out:
#                                                      0 Text Word
# 0                                       /manifest.json  NaN  NaN
# 1    https://www.infowars.com/wp-content/themes/inf...  NaN  NaN
# 2                                    //gmpg.org/xfn/11  NaN  NaN
# 3                  https://www.infowars.com/xmlrpc.php  NaN  NaN
# 4    https://cdnjs.cloudflare.com/ajax/libs/lightbo...  NaN  NaN
# ..                                                 ...  ...  ...
# 245             https://www.infowars.com/contributors/  NaN  NaN
# 246  https://www.infowars.com/2017-guide-to-infowar...  NaN  NaN
# 247  https://www.infowars.com/wp-content/plugins/re...  NaN  NaN
# 248  https://www.infowars.com/wp-content/plugins/re...  NaN  NaN
# 249   $(this).attr('href');old_target = typeof $(th...  NaN  NaN
#
# [250 rows x 3 columns]

# %%
df.to_csv('C:/Curso-ML-1/project/source-inf.csv')
