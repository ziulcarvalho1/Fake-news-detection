# %% [markdown]
# # Web Scraping - for fake news

# %%
import requests
import nltk
import urllib.request
import time
from bs4 import BeautifulSoup
from newspaper import Article

# %%
URL = 'https://www.reuters.com/article/us-health-coronavirus-canada/canada-posts-one-of-its-smallest-daily-increases-in-coronavirus-deaths-idUSKBN22M0L8'
article = Article(URL)

# %%
article.download()
article.parse()
nltk.download('punkt')
article.nlp()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ziulc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
article.authors
# Out:
# ['Reuters Editorial', 'Min Read']

# %%
article.publish_date
# Out:
# datetime.datetime(2020, 5, 10, 17, 38, 29, tzinfo=tzutc())

# %%
article.top_image
# Out:
# 'https://s4.reutersmedia.net/resources/r/?m=02&d=20200510&t=2&i=1518111083&w=1200&r=LYNXMPEG490H8'

# %%
article.text
# Out:
# "A worker looks out after police officers placed butterfly stickers on windows at Orchard Villa Retirement Residence on Mother's Day, after several residents died of the coronavirus disease (COVID-19) in Pickering, Ontario, Canada May 10, 2020. REUTERS/Carlos Osorio\n\nOTTAWA (Reuters) - The total number of people killed by the coronavirus in Canada rose by 2.2% to 4,728 on Sunday, one of the lowest daily increases since the outbreak started, official public health agency data showed.\n\n“We have come a long way in a short time since the COVID-19 pandemic was declared and our efforts have undoubtedly prevented wider spread of the virus across the country,” chief public health officer Theresa Tam said in a statement.\n\nThe figure for those diagnosed with the coronavirus rose to 67,996. On Saturday there were 4,628 deaths and 66,780 positive diagnoses.\n\nSeparately, Ontario - the most populous of the 10 provinces - reported just 294 new cases on Sunday, the lowest day-on-day advance 
# ...

# %%
article.title
# Out:
# 'Canada posts one of its smallest daily increases in coronavirus deaths'

# %%
article.summary
# Out:
# "A worker looks out after police officers placed butterfly stickers on windows at Orchard Villa Retirement Residence on Mother's Day, after several residents died of the coronavirus disease (COVID-19) in Pickering, Ontario, Canada May 10, 2020.\nREUTERS/Carlos OsorioOTTAWA (Reuters) - The total number of people killed by the coronavirus in Canada rose by 2.2% to 4,728 on Sunday, one of the lowest daily increases since the outbreak started, official public health agency data showed.\nThe figure for those diagnosed with the coronavirus rose to 67,996.\nSeveral provinces are moving to gradually reopen businesses that were shut down to fight the outbreak, throwing millions out of work.\nPrime Minister Justin Trudeau said on Saturday that if provinces acted too quickly, a second wave of the pandemic could send Canada “back into confinement this summer”."

# %%
URL1 = 'https://www.reuters.com/news/world'
article1 = Article(URL1)

# %%
article1.text
# Out:
# ''

# %%
request1 = requests.get(URL1)

# %%
print(request1)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(request1.content, 'html.parser')

# %%
print(soup)
# Out:
# <!--[if !IE]> App Server /produs--i-060ae1fb70e9f07bf/ <![endif]-->
# <!DOCTYPE html>
# <html data-edition="BETAUS" lang="en">
# <head>
# <title>World News | Reuters.com</title>
# <meta content="SVDMcE-27ZUUuh-EcZzejAJ0YIFjxD9H_nwAX6YVTw4" name="google-site-verification"/>
# <meta content="H9ahVdRxjlM56O9Un526uBCSaj_izzkfUjOCS--Zpco" name="google-site-verification"/>
# ...
